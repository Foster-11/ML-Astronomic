# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sdss_sample.csv')

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   u             1000 non-null   float64
#  1   g             1000 non-null   float64
#  2   r             1000 non-null   float64
#  3   i             1000 non-null   float64
#  4   z             1000 non-null   float64
#  5   redshift      1000 non-null   float64
#  6   class         1000 non-null   object
#  7   snr_r         1000 non-null   float64
#  8   extinction_r  1000 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 70.4+ KB
#            u          g          r          i          z  redshift   class  \
# 0  19.363821  19.460918  19.584009  19.456054  19.658009  0.293418  Galaxy
# 1  20.290443  20.205250  19.844603  20.338405  20.227140  1.996765     QSO
# 2  20.212454  20.470242  20.206240  20.145376  20.248270  2.059417     QSO
# ...

# %%
df.describe()
# Out:
#                  u            g            r            i            z  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     18.802552    18.766696    18.781754    18.804519    18.809589
# std       1.677592     1.580087     1.501386     1.494232     1.483115
# min      15.573337    15.662415    15.705476    15.989884    16.013314
# 25%      16.780979    16.865832    16.946810    17.020835    17.035003
# 50%      19.659242    19.591672    19.551549    19.480428    19.449826
# 75%      20.115844    20.018099    19.964117    19.988998    20.033591
# max      21.508410    21.100116    20.843549    21.172378    21.010498
#
#           redshift        snr_r  extinction_r
# count  1000.000000  1000.000000   1000.000000
# mean      0.588040    15.761853      0.078741
# std       0.802934     4.437600      0.029156
# min       0.000000    10.191070      0.000000
# 25%       0.001393    12.406214      0.060072
# 50%       0.213444    13.530189      0.077930
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                      u         g         r         i         z  redshift  \
# u             1.000000  0.946601  0.951755  0.945797  0.948057  0.586929
# g             0.946601  1.000000  0.954216  0.951049  0.950163  0.588246
# r             0.951755  0.954216  1.000000  0.958514  0.957616  0.618789
# i             0.945797  0.951049  0.958514  1.000000  0.960288  0.650440
# z             0.948057  0.950163  0.957616  0.960288  1.000000  0.659565
# redshift      0.586929  0.588246  0.618789  0.650440  0.659565  1.000000
# snr_r        -0.886720 -0.895806 -0.934485 -0.897017 -0.892095 -0.546995
# extinction_r -0.045787 -0.040368 -0.046855 -0.043367 -0.059174 -0.041695
#
#                  snr_r  extinction_r
# u            -0.886720     -0.045787
# g            -0.895806     -0.040368
# r            -0.934485     -0.046855
# i            -0.897017     -0.043367
# z            -0.892095     -0.059174
# redshift     -0.546995     -0.041695
# snr_r         1.000000      0.042095
# ...

# %%
df.corr(numeric_only=True)['redshift'].sort_values(ascending=False)
# Out:
# redshift        1.000000
# z               0.659565
# i               0.650440
# r               0.618789
# g               0.588246
# u               0.586929
# extinction_r   -0.041695
# snr_r          -0.546995
# Name: redshift, dtype: float64

# %%
df.hist(bins=20, figsize=(12,8))
plt.show()
